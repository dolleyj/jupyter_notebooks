# %%
import pandas as pd

file = '/home/dustin/Downloads/U.S.DividendChampions.xls'

df = pd.read_excel(file, sheet_name='Champions', skiprows=[0,1,2,3,4])
df
# Out:
#                                  Name Symbol                 Industry  \
# 0                    1st Source Corp.   SRCE                  Banking
# 1                          3M Company    MMM             Conglomerate
# 2                    A.O. Smith Corp.    AOS     Industrial Equipment
# 3                 ABM Industries Inc.    ABM        Business Services
# 4                          AFLAC Inc.    AFL                Insurance
# 5                Air Products & Chem.    APD       Chemical-Specialty
# 6                   Altria Group Inc.     MO                  Tobacco
# 7               American States Water    AWR            Utility-Water
# 8                   Aqua America Inc.    WTR            Utility-Water
# 9              Archer Daniels Midland    ADM              Agriculture
# 10                          AT&T Inc.      T       Telecommunications
# 11                       Atmos Energy    ATO              Utility-Gas
# ...

# %%
df.columns
# Out:
# Index([     'Name',    'Symbol',  'Industry',       'Yrs',       'Seq',
#               'DR',        'SP',     'Price',     'Yield',       'Old',
#              'New',      'Inc.',    'Ex-Div',    'Record',       'Pay',
#              'Sch',      'Note',  'Dividend',    'Payout',    'Graham',
#              'P/E',     'Month',       'EPS',     'Ratio',   'P/Sales',
#           'P/Book',       'ROE',    'Growth',  'Growth.1',  'Growth.2',
#         'Growth.3',         'A',    '($Mil)',      'Own.',    'Equity',
#              'DEG',      'A/D*',      '1-yr',      '3-yr',      '5-yr',
#            '10-yr',        2017,        2016,        2015,        2014,
#               2013,         '#',        2012,        2011,       '#.1',
#               2010,        2009,        2008,        2007,        2006,
#               2005,        2004,        2003,        2002,        2001,
#               2000,        1999,   'RegDivs',    '2016.1',    '2015.1',
# ...

# %%
# REGULAR STOCKS
# Payout < 60%
new_df = df.loc[df.Payout < 60]

# If Yield > 2.0 and < 2.5 and Rule > 16
# If Yield > 2.5 and < 3.0 and Rule > 14
# If Yield > 3.0 and Rule > 12

# MLPs, REIT, Utilities, & Telecoms
# Yield > 4.0
# Rule > 8
# 1-yr, 3-yr, 3-yr, 10-yr ALL > 3.5
new_df

# Cookbook: http://pandas.pydata.org/pandas-docs/stable/cookbook.html
# Out:
#                               Name Symbol                 Industry        Yrs  \
# 0                 1st Source Corp.   SRCE                  Banking  31.000000
# 1                       3M Company    MMM             Conglomerate  60.000000
# 2                 A.O. Smith Corp.    AOS     Industrial Equipment  25.000000
# 3              ABM Industries Inc.    ABM        Business Services  51.000000
# 4                       AFLAC Inc.    AFL                Insurance  36.000000
# 7            American States Water    AWR            Utility-Water  63.000000
# 11                    Atmos Energy    ATO              Utility-Gas  34.000000
# 13               Badger Meter Inc.    BMI     Industrial Equipment  25.000000
# 16               Black Hills Corp.    BKH         Utility-Electric  47.000000
# 17                     Brady Corp.    BRC        Business Services  32.000000
# 18            Brown-Forman Class B   BF-B      Beverages-Alcoholic  34.000000
# ...
